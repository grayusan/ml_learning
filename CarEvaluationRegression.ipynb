# %%
import pathlib 

import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

dataset_path = keras.utils.get_file("car.data", "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data")

column_names = ['buying', "maint", "doors", "persons", "lug_boot", "safety", "value"]

raw_dataset = pd.read_csv(dataset_path, names=column_names, na_values = "?", comment='\t', sep=" ", skipinitialspace=True)

dataset = raw_dataset.copy()

dataset
# Out:
#                                  buying  maint  doors  ...  lug_boot  safety  value
# 0       vhigh,vhigh,2,2,small,low,unacc    NaN    NaN  ...       NaN     NaN    NaN
# 1       vhigh,vhigh,2,2,small,med,unacc    NaN    NaN  ...       NaN     NaN    NaN
# 2      vhigh,vhigh,2,2,small,high,unacc    NaN    NaN  ...       NaN     NaN    NaN
# 3         vhigh,vhigh,2,2,med,low,unacc    NaN    NaN  ...       NaN     NaN    NaN
# 4         vhigh,vhigh,2,2,med,med,unacc    NaN    NaN  ...       NaN     NaN    NaN
# ...                                 ...    ...    ...  ...       ...     ...    ...
# 1723    low,low,5more,more,med,med,good    NaN    NaN  ...       NaN     NaN    NaN
# 1724  low,low,5more,more,med,high,vgood    NaN    NaN  ...       NaN     NaN    NaN
# 1725   low,low,5more,more,big,low,unacc    NaN    NaN  ...       NaN     NaN    NaN
# 1726    low,low,5more,more,big,med,good    NaN    NaN  ...       NaN     NaN    NaN
# 1727  low,low,5more,more,big,high,vgood    NaN    NaN  ...       NaN     NaN    NaN
#
# [1728 rows x 7 columns]
